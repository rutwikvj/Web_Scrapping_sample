# %%
import pandas as pd
import seaborn as sns

# %%
url='https://en.wikipedia.org/wiki/World_population'

# %%
tables=pd.read_html(url)

# %%
pop_table=tables[4]
pop_table
# Out:
#    Rank        Country  Population  % of world         Date  \
# 0     1          China  1409783840         NaN  18 Sep 2021
# 1     2          India  1382035314         NaN  18 Sep 2021
# 2     3  United States   332384562         NaN  18 Sep 2021
# 3     4      Indonesia   269603400         NaN   1 Jul 2020
# 4     5       Pakistan   220892331         NaN   1 Jul 2020
# 5     6         Brazil   213693255         NaN  18 Sep 2021
# 6     7        Nigeria   206139587         NaN   1 Jul 2020
# 7     8     Bangladesh   171376204         NaN  18 Sep 2021
# 8     9         Russia   146748590         NaN   1 Jan 2020
# 9    10         Mexico   127792286         NaN   1 Jul 2020
#
#            Source(official or UN)
# 0   National population clock[89]
# 1   National population clock[90]
# 2   National population clock[91]
# 3  National annual projection[92]
# 4               UN Projection[93]
# 5   National population clock[94]
# 6               UN Projection[93]
# ...

# %%
sns.barplot(data=pop_table,y='Country',x='Population')
# Out:
# <AxesSubplot:xlabel='Population', ylabel='Country'>

# %%
url2='https://en.wikipedia.org/wiki/Languages_of_India'

# %%
tables=pd.read_html(url2)

# %%
lan_table=tables[2]
lan_table
# Out:
#      Language  First languagespeakers[44]  \
# 0       Hindi                   528347193
# 1     English                      259678
# 2     Bengali                    97237669
# 3     Marathi                    83026680
# 4      Telugu                    81127740
# 5       Tamil                    69026881
# 6    Gujarati                    55492554
# 7        Urdu                    50772631
# 8     Kannada                    43706512
# 9        Odia                    37521324
# 10  Malayalam                    34838819
# 11    Punjabi                    33124726
# 12   Assamese                    15311351
# 13   Maithili                    13583464
# 14   Sanskrit                       24821
#
#     First languagespeakers as a percentageof total population  \
# 0                                            43.63000
# 1                                             0.02000
# 2                                             8.30000
# 3                                             6.86000
# ...

# %%
sns.barplot(data=lan_table,x='Total speakers (millions)[45]',y='Language')
# Out:
# <AxesSubplot:xlabel='Total speakers (millions)[45]', ylabel='Language'>

# %%
ipl='https://www.iplt20.com/points-table/men/2018'
tables=pd.read_html(ipl)

# %%
ipl_tab=tables[0]

# %%
ipl_tab
# Out:
#   Unnamed: 0                              Team  Pld  Won  Lost  Tied  N/R  \
# 0          Q          Sunrisers Hyderabad  SRH   14    9     5     0    0
# 1          Q          Chennai Super Kings  CSK   14    9     5     0    0
# 2          Q        Kolkata Knight Riders  KKR   14    8     6     0    0
# 3          Q              Rajasthan Royals  RR   14    7     7     0    0
# 4          5                Mumbai Indians  MI   14    6     8     0    0
# 5          6  Royal Challengers Bangalore  RCB   14    6     8     0    0
# 6          7                Punjab Kings  PBKS   14    6     8     0    0
# 7          8                Delhi Capitals  DC   14    5     9     0    0
#
#    Net RR          For      Against  Pts           Form
# 0   0.284  2,230/273.3  2,193/278.4   18  L  L  L  W  W
# 1   0.253  2,488/275.3  2,433/277.1   18  W  L  W  L  W
# 2  -0.070  2,363/265.1    2,425/270   16  W  W  W  L  L
# 3  -0.250  2,130/255.3  2,141/249.2   14  W  L  W  W  W
# ...

# %%
sns.barplot(data=ipl_tab,x='Pts',y='Team')
# Out:
# <AxesSubplot:xlabel='Pts', ylabel='Team'>
